# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from random import randint
import random
import time
import os
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = "/content/drive/Shared drives/MotionAI/"

# %% [markdown]
# ### Load Data

# %%
df = pd.read_csv(path+'batch1.csv')

# %%
# Split into seq blocks
n_steps = 24
n_blocks = df.shape[0]/n_steps

X = np.split(df.iloc[:,5:].values, n_blocks)

y = df['Label'].values
y = [y[i] for i in range(0,len(y),n_steps)]

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %%
# Remove null seqs
a = np.ones((24,36))*-1
null_seq = []
for i in range(len(X)):
  if np.array_equal(X[i], a):
    null_seq.append(i)
    
X = np.array([X[i] for i in range(len(X)) if i not in null_seq])
y = np.array([y[i] for i in range(len(y)) if i not in null_seq])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# %% [markdown]
# ### Create Model

# %%
def LSTM_RNN(_X, _weights, _biases):
    # model architecture based on "guillaume-chevalier" and "aymericdamien" under the MIT license.

    _X = tf.transpose(_X, [1, 0, 2])  # permute n_steps and batch_size
    _X = tf.reshape(_X, [-1, n_input])   
    # Rectifies Linear Unit activation function used
    _X = tf.nn.relu(tf.matmul(_X, _weights['hidden']) + _biases['hidden'])
    # Split data because rnn cell needs a list of inputs for the RNN inner loop
    _X = tf.split(_X, n_steps, 0) 

    # Define two stacked LSTM cells (two recurrent layers deep) with tensorflow
    lstm_cell_1 = tf.contrib.rnn.BasicLSTMCell(n_hidden, forget_bias=1.0, state_is_tuple=True)
    lstm_cell_2 = tf.contrib.rnn.BasicLSTMCell(n_hidden, forget_bias=1.0, state_is_tuple=True)
    lstm_cells = tf.contrib.rnn.MultiRNNCell([lstm_cell_1, lstm_cell_2], state_is_tuple=True)
    outputs, states = tf.contrib.rnn.static_rnn(lstm_cells, _X, dtype=tf.float32)

    lstm_last_output = outputs[-1]
    
    # Linear activation
    return tf.matmul(lstm_last_output, _weights['out']) + _biases['out']


def extract_batch_size(_train, _labels, _unsampled, batch_size):
    # Fetch a "batch_size" amount of data and labels from "(X|y)_train" data. 
    # Elements of each batch are chosen randomly, without replacement, from X_train with corresponding label from Y_train
    # unsampled_indices keeps track of sampled data ensuring non-replacement. Resets when remaining datapoints < batch_size    
    
    shape = list(_train.shape)
    shape[0] = batch_size
    batch_s = np.empty(shape)
    batch_labels = np.empty((batch_size,1)) 

    for i in range(batch_size):
        # Loop index
        # index = random sample from _unsampled (indices)
        index = random.choice(_unsampled)
        batch_s[i] = _train[index] 
        batch_labels[i] = _labels[index]
        _unsampled.remove(index)


    return batch_s, batch_labels, _unsampled


def one_hot(y_):
    
    y_ = y_.reshape(len(y_))
    n_values = int(np.max(y_)) + 1
    return np.eye(n_values)[np.array(y_, dtype=np.int32)]  # Returns FLOATS

# %%
tf.reset_default_graph()

training_data_count = len(X_train)  
test_data_count = len(X_test)  
n_input = len(X_train[0][0])  

n_hidden = 36 # Hidden layer num of features
n_classes = 4 

#updated for learning-rate decay
# calculated as: decayed_learning_rate = learning_rate * decay_rate ^ (global_step / decay_steps)
decaying_learning_rate = True
learning_rate = 0.0025 #used if decaying_learning_rate set to False
init_learning_rate = 0.005
decay_rate = 0.96 #the base of the exponential in the decay
decay_steps = 100000 #used in decay every 60000 steps with a base of 0.96

global_step = tf.Variable(0, trainable=False)
lambda_loss_amount = 0.0015

training_iters = training_data_count *20  
batch_size = 1
display_iter = batch_size*8  # To show test set accuracy during training

x = tf.placeholder(tf.float32, [None, n_steps, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])

# Graph weights
weights = {
    'hidden': tf.Variable(tf.random_normal([n_input, n_hidden])), # Hidden layer weights
    'out': tf.Variable(tf.random_normal([n_hidden, n_classes], mean=1.0))
}
biases = {
    'hidden': tf.Variable(tf.random_normal([n_hidden])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

pred = LSTM_RNN(x, weights, biases)

# Loss, optimizer and evaluation
l2 = lambda_loss_amount * sum(
    tf.nn.l2_loss(tf_var) for tf_var in tf.trainable_variables()
) # L2 loss prevents this overkill neural network to overfit the data
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=pred)) + l2 # Softmax loss
if decaying_learning_rate:
    learning_rate = tf.train.exponential_decay(init_learning_rate, global_step*batch_size, decay_steps, decay_rate, staircase=True)


#decayed_learning_rate = learning_rate * decay_rate ^ (global_step / decay_steps) #exponentially decayed learning rate
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost,global_step=global_step) # Adam Optimizer

correct_pred = tf.equal(tf.argmax(pred,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# %%
test_losses = []
test_accuracies = []
train_losses = []
train_accuracies = []
sess = tf.InteractiveSession(config=tf.ConfigProto(log_device_placement=True))
init = tf.global_variables_initializer()
sess.run(init)

# Perform Training steps with "batch_size" amount of data at each loop. 
# Elements of each batch are chosen randomly, without replacement, from X_train, 
# restarting when remaining datapoints < batch_size
step = 1
time_start = time.time()
unsampled_indices = list(range(0,len(X_train)))

while step * batch_size <= training_iters:
    #print (sess.run(learning_rate)) #decaying learning rate
    #print (sess.run(global_step)) # global number of iterations
    if len(unsampled_indices) < batch_size:
        unsampled_indices = list(range(0,len(X_train))) 
    batch_xs, raw_labels, unsampled_indicies = extract_batch_size(X_train, y_train, unsampled_indices, batch_size)
    batch_ys = one_hot(raw_labels)
    # check that encoded output is same length as num_classes, if not, pad it 
    if len(batch_ys[0]) < n_classes:
        temp_ys = np.zeros((batch_size, n_classes))
        temp_ys[:batch_ys.shape[0],:batch_ys.shape[1]] = batch_ys
        batch_ys = temp_ys
       
    

    # Fit training using batch data
    _, loss, acc = sess.run(
        [optimizer, cost, accuracy],
        feed_dict={
            x: batch_xs, 
            y: batch_ys
        }
    )
    train_losses.append(loss)
    train_accuracies.append(acc)
    
    # Evaluate network only at some steps for faster training: 
    if (step*batch_size % display_iter == 0) or (step == 1) or (step * batch_size > training_iters):
        
        # To not spam console, show training accuracy/loss in this "if"
        print("Iter #" + str(step*batch_size) + \
              ":  Learning rate = " + "{:.6f}".format(sess.run(learning_rate)) + \
              ":   Batch Loss = " + "{:.6f}".format(loss) + \
              ", Accuracy = {}".format(acc))
        
        # Evaluation on the test set (no learning made here - just evaluation for diagnosis)
        loss, acc = sess.run(
            [cost, accuracy], 
            feed_dict={
                x: X_test,
                y: one_hot(y_test)
            }
        )
        test_losses.append(loss)
        test_accuracies.append(acc)
        print("PERFORMANCE ON TEST SET:             " + \
              "Batch Loss = {}".format(loss) + \
              ", Accuracy = {}".format(acc))

    step += 1

print("Optimization Finished!")

# Accuracy for test data

one_hot_predictions, accuracy, final_loss = sess.run(
    [pred, accuracy, cost],
    feed_dict={
        x: X_test,
        y: one_hot(y_test)
    }
)

test_losses.append(final_loss)
test_accuracies.append(accuracy)

print("FINAL RESULT: " + \
      "Batch Loss = {}".format(final_loss) + \
      ", Accuracy = {}".format(accuracy))
time_stop = time.time()
print("TOTAL TIME:  {}".format(time_stop - time_start))
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py:1735: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# Iter #1:  Learning rate = 0.005000:   Batch Loss = 9.423869, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 3.0917696952819824, Accuracy = 0.1515151560306549
# Iter #8:  Learning rate = 0.005000:   Batch Loss = 3.952465, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.5601401329040527, Accuracy = 0.6060606241226196
# Iter #16:  Learning rate = 0.005000:   Batch Loss = 2.411434, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.8225250244140625, Accuracy = 0.39393940567970276
# Iter #24:  Learning rate = 0.005000:   Batch Loss = 3.038686, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.461700916290283, Accuracy = 0.6363636255264282
# Iter #32:  Learning rate = 0.005000:   Batch Loss = 4.553239, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.3154406547546387, Accuracy = 0.6666666865348816
# Iter #40:  Learning rate = 0.005000:   Batch Loss = 1.446113, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.5265395641326904, Accuracy = 0.4545454680919647
# Iter #48:  Learning rate = 0.005000:   Batch Loss = 3.306982, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.7089827060699463, Accuracy = 0.5454545617103577
# Iter #56:  Learning rate = 0.005000:   Batch Loss = 5.204868, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 3.043745517730713, Accuracy = 0.3030303120613098
# Iter #64:  Learning rate = 0.005000:   Batch Loss = 4.036798, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.6558620929718018, Accuracy = 0.42424243688583374
# Iter #72:  Learning rate = 0.005000:   Batch Loss = 2.411854, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.4813590049743652, Accuracy = 0.42424243688583374
# Iter #80:  Learning rate = 0.005000:   Batch Loss = 2.191338, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.3782668113708496, Accuracy = 0.5454545617103577
# Iter #88:  Learning rate = 0.005000:   Batch Loss = 2.136931, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.4026403427124023, Accuracy = 0.6060606241226196
# Iter #96:  Learning rate = 0.005000:   Batch Loss = 2.237021, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.475590467453003, Accuracy = 0.6060606241226196
# Iter #104:  Learning rate = 0.005000:   Batch Loss = 1.943249, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.3040685653686523, Accuracy = 0.5757575631141663
# Iter #112:  Learning rate = 0.005000:   Batch Loss = 2.524886, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.245910167694092, Accuracy = 0.6969696879386902
# Iter #120:  Learning rate = 0.005000:   Batch Loss = 1.668129, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.2319228649139404, Accuracy = 0.5454545617103577
# Iter #128:  Learning rate = 0.005000:   Batch Loss = 3.287527, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.307310104370117, Accuracy = 0.42424243688583374
# Iter #136:  Learning rate = 0.005000:   Batch Loss = 2.978614, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.484837055206299, Accuracy = 0.4545454680919647
# Iter #144:  Learning rate = 0.005000:   Batch Loss = 2.450594, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.1316184997558594, Accuracy = 0.5757575631141663
# Iter #152:  Learning rate = 0.005000:   Batch Loss = 2.352025, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.08268666267395, Accuracy = 0.6969696879386902
# Iter #160:  Learning rate = 0.005000:   Batch Loss = 2.149528, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.177302837371826, Accuracy = 0.6060606241226196
# Iter #168:  Learning rate = 0.005000:   Batch Loss = 1.615599, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.1818509101867676, Accuracy = 0.5151515007019043
# Iter #176:  Learning rate = 0.005000:   Batch Loss = 2.307381, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.183112621307373, Accuracy = 0.42424243688583374
# Iter #184:  Learning rate = 0.005000:   Batch Loss = 2.405141, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.0632317066192627, Accuracy = 0.6363636255264282
# Iter #192:  Learning rate = 0.005000:   Batch Loss = 4.291590, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.091153860092163, Accuracy = 0.7272727489471436
# Iter #200:  Learning rate = 0.005000:   Batch Loss = 2.702333, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.1080422401428223, Accuracy = 0.6969696879386902
# Iter #208:  Learning rate = 0.005000:   Batch Loss = 1.731525, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.2560060024261475, Accuracy = 0.3636363744735718
# Iter #216:  Learning rate = 0.005000:   Batch Loss = 1.760912, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.276090145111084, Accuracy = 0.3333333432674408
# Iter #224:  Learning rate = 0.005000:   Batch Loss = 2.261711, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.1929070949554443, Accuracy = 0.39393940567970276
# Iter #232:  Learning rate = 0.005000:   Batch Loss = 2.708615, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.0461795330047607, Accuracy = 0.5454545617103577
# Iter #240:  Learning rate = 0.005000:   Batch Loss = 1.431181, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.028268814086914, Accuracy = 0.5454545617103577
# Iter #248:  Learning rate = 0.005000:   Batch Loss = 3.626996, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.1203248500823975, Accuracy = 0.42424243688583374
# Iter #256:  Learning rate = 0.005000:   Batch Loss = 1.550683, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.065124273300171, Accuracy = 0.5454545617103577
# Iter #264:  Learning rate = 0.005000:   Batch Loss = 2.377334, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.1324753761291504, Accuracy = 0.5757575631141663
# Iter #272:  Learning rate = 0.005000:   Batch Loss = 1.801952, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.0447208881378174, Accuracy = 0.6363636255264282
# Iter #280:  Learning rate = 0.005000:   Batch Loss = 1.938341, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.9704830646514893, Accuracy = 0.6666666865348816
# Iter #288:  Learning rate = 0.005000:   Batch Loss = 4.997093, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.0238454341888428, Accuracy = 0.5151515007019043
# Iter #296:  Learning rate = 0.005000:   Batch Loss = 1.624410, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.0241103172302246, Accuracy = 0.42424243688583374
# Iter #304:  Learning rate = 0.005000:   Batch Loss = 2.385252, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.9139125347137451, Accuracy = 0.6060606241226196
# Iter #312:  Learning rate = 0.005000:   Batch Loss = 1.246431, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.337820529937744, Accuracy = 0.39393940567970276
# Iter #320:  Learning rate = 0.005000:   Batch Loss = 2.607695, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.0771846771240234, Accuracy = 0.4545454680919647
# Iter #328:  Learning rate = 0.005000:   Batch Loss = 1.990685, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.9183763265609741, Accuracy = 0.5757575631141663
# Iter #336:  Learning rate = 0.005000:   Batch Loss = 1.527903, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.9771361351013184, Accuracy = 0.5454545617103577
# Iter #344:  Learning rate = 0.005000:   Batch Loss = 1.472900, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.012773275375366, Accuracy = 0.42424243688583374
# Iter #352:  Learning rate = 0.005000:   Batch Loss = 2.851853, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.117579460144043, Accuracy = 0.5454545617103577
# Iter #360:  Learning rate = 0.005000:   Batch Loss = 1.441578, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 2.0168824195861816, Accuracy = 0.4848484992980957
# Iter #368:  Learning rate = 0.005000:   Batch Loss = 1.248229, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.9911623001098633, Accuracy = 0.42424243688583374
# Iter #376:  Learning rate = 0.005000:   Batch Loss = 1.630530, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.9605967998504639, Accuracy = 0.42424243688583374
# Iter #384:  Learning rate = 0.005000:   Batch Loss = 1.261882, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.9307302236557007, Accuracy = 0.5151515007019043
# Iter #392:  Learning rate = 0.005000:   Batch Loss = 1.134537, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.8698246479034424, Accuracy = 0.5454545617103577
# Iter #400:  Learning rate = 0.005000:   Batch Loss = 2.029305, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.8243162631988525, Accuracy = 0.6363636255264282
# Iter #408:  Learning rate = 0.005000:   Batch Loss = 1.544325, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.8973946571350098, Accuracy = 0.5454545617103577
# Iter #416:  Learning rate = 0.005000:   Batch Loss = 1.286978, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.8285176753997803, Accuracy = 0.5151515007019043
# Iter #424:  Learning rate = 0.005000:   Batch Loss = 3.594650, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.8443577289581299, Accuracy = 0.5454545617103577
# Iter #432:  Learning rate = 0.005000:   Batch Loss = 1.386626, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.8132259845733643, Accuracy = 0.6060606241226196
# Iter #440:  Learning rate = 0.005000:   Batch Loss = 1.197912, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.7770503759384155, Accuracy = 0.6363636255264282
# Iter #448:  Learning rate = 0.005000:   Batch Loss = 1.168331, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.743163824081421, Accuracy = 0.6666666865348816
# Iter #456:  Learning rate = 0.005000:   Batch Loss = 2.633147, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.7198379039764404, Accuracy = 0.6666666865348816
# Iter #464:  Learning rate = 0.005000:   Batch Loss = 1.918515, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.744363784790039, Accuracy = 0.6060606241226196
# Iter #472:  Learning rate = 0.005000:   Batch Loss = 1.981866, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.8099498748779297, Accuracy = 0.4545454680919647
# Iter #480:  Learning rate = 0.005000:   Batch Loss = 1.334470, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.899043321609497, Accuracy = 0.5454545617103577
# Iter #488:  Learning rate = 0.005000:   Batch Loss = 1.540511, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.9610918760299683, Accuracy = 0.5757575631141663
# Iter #496:  Learning rate = 0.005000:   Batch Loss = 1.265212, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.9252374172210693, Accuracy = 0.5454545617103577
# Iter #504:  Learning rate = 0.005000:   Batch Loss = 4.762948, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.8877688646316528, Accuracy = 0.5757575631141663
# Iter #512:  Learning rate = 0.005000:   Batch Loss = 3.597525, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.7885141372680664, Accuracy = 0.5151515007019043
# Iter #520:  Learning rate = 0.005000:   Batch Loss = 3.796399, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.7702651023864746, Accuracy = 0.4848484992980957
# Iter #528:  Learning rate = 0.005000:   Batch Loss = 2.288034, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.7299333810806274, Accuracy = 0.5757575631141663
# Iter #536:  Learning rate = 0.005000:   Batch Loss = 1.901110, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.7436259984970093, Accuracy = 0.5757575631141663
# Iter #544:  Learning rate = 0.005000:   Batch Loss = 1.463675, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.7634601593017578, Accuracy = 0.5757575631141663
# Iter #552:  Learning rate = 0.005000:   Batch Loss = 1.591605, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.817453145980835, Accuracy = 0.4848484992980957
# Iter #560:  Learning rate = 0.005000:   Batch Loss = 1.268912, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.8916583061218262, Accuracy = 0.4848484992980957
# Iter #568:  Learning rate = 0.005000:   Batch Loss = 1.747244, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.6895197629928589, Accuracy = 0.7272727489471436
# Iter #576:  Learning rate = 0.005000:   Batch Loss = 1.213789, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.650635838508606, Accuracy = 0.6969696879386902
# Iter #584:  Learning rate = 0.005000:   Batch Loss = 1.929043, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.7073594331741333, Accuracy = 0.5757575631141663
# Iter #592:  Learning rate = 0.005000:   Batch Loss = 1.246681, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.7681925296783447, Accuracy = 0.5454545617103577
# Iter #600:  Learning rate = 0.005000:   Batch Loss = 1.752281, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.766116976737976, Accuracy = 0.42424243688583374
# Iter #608:  Learning rate = 0.005000:   Batch Loss = 4.450209, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.689197063446045, Accuracy = 0.6060606241226196
# Iter #616:  Learning rate = 0.005000:   Batch Loss = 1.588725, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.6994330883026123, Accuracy = 0.5757575631141663
# Iter #624:  Learning rate = 0.005000:   Batch Loss = 1.240560, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.6565401554107666, Accuracy = 0.6969696879386902
# Iter #632:  Learning rate = 0.005000:   Batch Loss = 1.021072, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.648555874824524, Accuracy = 0.7272727489471436
# Iter #640:  Learning rate = 0.005000:   Batch Loss = 1.146437, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.658107042312622, Accuracy = 0.6363636255264282
# Iter #648:  Learning rate = 0.005000:   Batch Loss = 1.251666, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.709862232208252, Accuracy = 0.6363636255264282
# Iter #656:  Learning rate = 0.005000:   Batch Loss = 1.435302, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.7340905666351318, Accuracy = 0.6363636255264282
# Iter #664:  Learning rate = 0.005000:   Batch Loss = 1.730369, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.6332354545593262, Accuracy = 0.6666666865348816
# Iter #672:  Learning rate = 0.005000:   Batch Loss = 1.485655, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.6469495296478271, Accuracy = 0.6060606241226196
# Iter #680:  Learning rate = 0.005000:   Batch Loss = 1.090432, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.7396998405456543, Accuracy = 0.4848484992980957
# Iter #688:  Learning rate = 0.005000:   Batch Loss = 3.898057, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.7077841758728027, Accuracy = 0.4545454680919647
# Iter #696:  Learning rate = 0.005000:   Batch Loss = 1.897321, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.668169379234314, Accuracy = 0.5151515007019043
# Iter #704:  Learning rate = 0.005000:   Batch Loss = 1.588660, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.672412633895874, Accuracy = 0.5454545617103577
# Iter #712:  Learning rate = 0.005000:   Batch Loss = 2.398390, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.7033729553222656, Accuracy = 0.42424243688583374
# Iter #720:  Learning rate = 0.005000:   Batch Loss = 1.545354, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.6324546337127686, Accuracy = 0.6969696879386902
# Iter #728:  Learning rate = 0.005000:   Batch Loss = 1.441404, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.603225588798523, Accuracy = 0.6363636255264282
# Iter #736:  Learning rate = 0.005000:   Batch Loss = 2.153992, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.675260305404663, Accuracy = 0.6060606241226196
# Iter #744:  Learning rate = 0.005000:   Batch Loss = 1.574447, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.6207239627838135, Accuracy = 0.6363636255264282
# Iter #752:  Learning rate = 0.005000:   Batch Loss = 1.482988, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.619079351425171, Accuracy = 0.6666666865348816
# Iter #760:  Learning rate = 0.005000:   Batch Loss = 2.757052, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.6658082008361816, Accuracy = 0.4545454680919647
# Iter #768:  Learning rate = 0.005000:   Batch Loss = 1.652892, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.656916856765747, Accuracy = 0.6363636255264282
# Iter #776:  Learning rate = 0.005000:   Batch Loss = 1.757902, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.614682674407959, Accuracy = 0.6363636255264282
# Iter #784:  Learning rate = 0.005000:   Batch Loss = 4.055035, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5734620094299316, Accuracy = 0.6969696879386902
# Iter #792:  Learning rate = 0.005000:   Batch Loss = 1.386259, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5558701753616333, Accuracy = 0.6969696879386902
# Iter #800:  Learning rate = 0.005000:   Batch Loss = 0.884565, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5725717544555664, Accuracy = 0.7272727489471436
# Iter #808:  Learning rate = 0.005000:   Batch Loss = 1.616375, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.628321647644043, Accuracy = 0.5454545617103577
# Iter #816:  Learning rate = 0.005000:   Batch Loss = 1.306050, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.6196266412734985, Accuracy = 0.5151515007019043
# Iter #824:  Learning rate = 0.005000:   Batch Loss = 1.186031, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5769598484039307, Accuracy = 0.5757575631141663
# Iter #832:  Learning rate = 0.005000:   Batch Loss = 1.593732, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.546379566192627, Accuracy = 0.5757575631141663
# Iter #840:  Learning rate = 0.005000:   Batch Loss = 1.974852, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5926103591918945, Accuracy = 0.5757575631141663
# Iter #848:  Learning rate = 0.005000:   Batch Loss = 1.045349, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5343382358551025, Accuracy = 0.6060606241226196
# Iter #856:  Learning rate = 0.005000:   Batch Loss = 1.151951, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4586827754974365, Accuracy = 0.7272727489471436
# Iter #864:  Learning rate = 0.005000:   Batch Loss = 1.809588, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4431519508361816, Accuracy = 0.6969696879386902
# Iter #872:  Learning rate = 0.005000:   Batch Loss = 1.256958, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5049543380737305, Accuracy = 0.6969696879386902
# Iter #880:  Learning rate = 0.005000:   Batch Loss = 0.758127, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.7624510526657104, Accuracy = 0.4848484992980957
# Iter #888:  Learning rate = 0.005000:   Batch Loss = 1.524077, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.9825916290283203, Accuracy = 0.4848484992980957
# Iter #896:  Learning rate = 0.005000:   Batch Loss = 0.743519, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.7840003967285156, Accuracy = 0.5454545617103577
# Iter #904:  Learning rate = 0.005000:   Batch Loss = 0.978718, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.613433837890625, Accuracy = 0.4848484992980957
# Iter #912:  Learning rate = 0.005000:   Batch Loss = 1.702658, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.59122633934021, Accuracy = 0.4545454680919647
# Iter #920:  Learning rate = 0.005000:   Batch Loss = 1.609344, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.510056495666504, Accuracy = 0.7272727489471436
# Iter #928:  Learning rate = 0.005000:   Batch Loss = 1.380632, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4597879648208618, Accuracy = 0.7272727489471436
# Iter #936:  Learning rate = 0.005000:   Batch Loss = 1.289924, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5016248226165771, Accuracy = 0.6969696879386902
# Iter #944:  Learning rate = 0.005000:   Batch Loss = 2.845460, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5262435674667358, Accuracy = 0.7272727489471436
# Iter #952:  Learning rate = 0.005000:   Batch Loss = 1.658528, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.534902572631836, Accuracy = 0.6969696879386902
# Iter #960:  Learning rate = 0.005000:   Batch Loss = 1.528031, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5204275846481323, Accuracy = 0.6969696879386902
# Iter #968:  Learning rate = 0.005000:   Batch Loss = 1.733352, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5022075176239014, Accuracy = 0.6666666865348816
# Iter #976:  Learning rate = 0.005000:   Batch Loss = 1.080276, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.493646502494812, Accuracy = 0.6666666865348816
# Iter #984:  Learning rate = 0.005000:   Batch Loss = 0.986413, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4744224548339844, Accuracy = 0.7272727489471436
# Iter #992:  Learning rate = 0.005000:   Batch Loss = 2.033697, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5190176963806152, Accuracy = 0.6969696879386902
# Iter #1000:  Learning rate = 0.005000:   Batch Loss = 1.163036, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5299729108810425, Accuracy = 0.6363636255264282
# Iter #1008:  Learning rate = 0.005000:   Batch Loss = 0.865416, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.559718132019043, Accuracy = 0.6060606241226196
# Iter #1016:  Learning rate = 0.005000:   Batch Loss = 4.364001, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5967869758605957, Accuracy = 0.6666666865348816
# Iter #1024:  Learning rate = 0.005000:   Batch Loss = 0.855451, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.58797025680542, Accuracy = 0.6363636255264282
# Iter #1032:  Learning rate = 0.005000:   Batch Loss = 1.155278, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.6402208805084229, Accuracy = 0.5757575631141663
# Iter #1040:  Learning rate = 0.005000:   Batch Loss = 2.429864, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.6321196556091309, Accuracy = 0.6060606241226196
# Iter #1048:  Learning rate = 0.005000:   Batch Loss = 0.943204, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.6029396057128906, Accuracy = 0.6363636255264282
# Iter #1056:  Learning rate = 0.005000:   Batch Loss = 1.175792, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.7512950897216797, Accuracy = 0.42424243688583374
# Iter #1064:  Learning rate = 0.005000:   Batch Loss = 0.742734, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.6005544662475586, Accuracy = 0.5454545617103577
# Iter #1072:  Learning rate = 0.005000:   Batch Loss = 1.881216, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5341850519180298, Accuracy = 0.6363636255264282
# Iter #1080:  Learning rate = 0.005000:   Batch Loss = 1.294099, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5655944347381592, Accuracy = 0.6363636255264282
# Iter #1088:  Learning rate = 0.005000:   Batch Loss = 1.056976, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5801639556884766, Accuracy = 0.6666666865348816
# Iter #1096:  Learning rate = 0.005000:   Batch Loss = 4.769591, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.6115483045578003, Accuracy = 0.6060606241226196
# Iter #1104:  Learning rate = 0.005000:   Batch Loss = 1.705026, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5408064126968384, Accuracy = 0.5757575631141663
# Iter #1112:  Learning rate = 0.005000:   Batch Loss = 1.008257, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5533900260925293, Accuracy = 0.6363636255264282
# Iter #1120:  Learning rate = 0.005000:   Batch Loss = 0.843575, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.6527082920074463, Accuracy = 0.6363636255264282
# Iter #1128:  Learning rate = 0.005000:   Batch Loss = 1.876583, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.7047832012176514, Accuracy = 0.5757575631141663
# Iter #1136:  Learning rate = 0.005000:   Batch Loss = 3.735911, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5655517578125, Accuracy = 0.5757575631141663
# Iter #1144:  Learning rate = 0.005000:   Batch Loss = 1.630493, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.6856043338775635, Accuracy = 0.6060606241226196
# Iter #1152:  Learning rate = 0.005000:   Batch Loss = 1.171927, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.7737085819244385, Accuracy = 0.42424243688583374
# Iter #1160:  Learning rate = 0.005000:   Batch Loss = 1.466879, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.7213935852050781, Accuracy = 0.5151515007019043
# Iter #1168:  Learning rate = 0.005000:   Batch Loss = 3.000747, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.6357090473175049, Accuracy = 0.6060606241226196
# Iter #1176:  Learning rate = 0.005000:   Batch Loss = 1.390672, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5126209259033203, Accuracy = 0.6060606241226196
# Iter #1184:  Learning rate = 0.005000:   Batch Loss = 1.704965, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4882736206054688, Accuracy = 0.5454545617103577
# Iter #1192:  Learning rate = 0.005000:   Batch Loss = 0.982083, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4497108459472656, Accuracy = 0.5757575631141663
# Iter #1200:  Learning rate = 0.005000:   Batch Loss = 1.136666, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4695277214050293, Accuracy = 0.7272727489471436
# Iter #1208:  Learning rate = 0.005000:   Batch Loss = 1.976363, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5746880769729614, Accuracy = 0.6363636255264282
# Iter #1216:  Learning rate = 0.005000:   Batch Loss = 0.710130, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.776274561882019, Accuracy = 0.4848484992980957
# Iter #1224:  Learning rate = 0.005000:   Batch Loss = 1.435746, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.7335234880447388, Accuracy = 0.5454545617103577
# Iter #1232:  Learning rate = 0.005000:   Batch Loss = 0.907658, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5494322776794434, Accuracy = 0.6666666865348816
# Iter #1240:  Learning rate = 0.005000:   Batch Loss = 0.756325, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5431435108184814, Accuracy = 0.6363636255264282
# Iter #1248:  Learning rate = 0.005000:   Batch Loss = 4.131907, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5301330089569092, Accuracy = 0.6060606241226196
# Iter #1256:  Learning rate = 0.005000:   Batch Loss = 0.967654, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.6118648052215576, Accuracy = 0.6363636255264282
# Iter #1264:  Learning rate = 0.005000:   Batch Loss = 3.587382, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5200443267822266, Accuracy = 0.6060606241226196
# Iter #1272:  Learning rate = 0.005000:   Batch Loss = 1.917674, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.465061068534851, Accuracy = 0.6969696879386902
# Iter #1280:  Learning rate = 0.005000:   Batch Loss = 1.383039, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4877625703811646, Accuracy = 0.6666666865348816
# Iter #1288:  Learning rate = 0.005000:   Batch Loss = 1.908295, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5418885946273804, Accuracy = 0.6060606241226196
# Iter #1296:  Learning rate = 0.005000:   Batch Loss = 1.112493, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5489988327026367, Accuracy = 0.6363636255264282
# Iter #1304:  Learning rate = 0.005000:   Batch Loss = 1.072059, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.547722339630127, Accuracy = 0.6666666865348816
# Iter #1312:  Learning rate = 0.005000:   Batch Loss = 2.059749, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5260429382324219, Accuracy = 0.6666666865348816
# Iter #1320:  Learning rate = 0.005000:   Batch Loss = 0.989318, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5187891721725464, Accuracy = 0.6363636255264282
# Iter #1328:  Learning rate = 0.005000:   Batch Loss = 1.967254, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5133039951324463, Accuracy = 0.6363636255264282
# Iter #1336:  Learning rate = 0.005000:   Batch Loss = 1.243349, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4939284324645996, Accuracy = 0.6666666865348816
# Iter #1344:  Learning rate = 0.005000:   Batch Loss = 1.571265, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4902217388153076, Accuracy = 0.6060606241226196
# Iter #1352:  Learning rate = 0.005000:   Batch Loss = 0.906659, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5015636682510376, Accuracy = 0.6060606241226196
# Iter #1360:  Learning rate = 0.005000:   Batch Loss = 0.660919, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5171756744384766, Accuracy = 0.6060606241226196
# Iter #1368:  Learning rate = 0.005000:   Batch Loss = 0.668728, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.6214770078659058, Accuracy = 0.5151515007019043
# Iter #1376:  Learning rate = 0.005000:   Batch Loss = 1.589218, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5711042881011963, Accuracy = 0.5454545617103577
# Iter #1384:  Learning rate = 0.005000:   Batch Loss = 0.709215, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5948457717895508, Accuracy = 0.5454545617103577
# Iter #1392:  Learning rate = 0.005000:   Batch Loss = 0.751968, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.489727258682251, Accuracy = 0.6060606241226196
# Iter #1400:  Learning rate = 0.005000:   Batch Loss = 1.676980, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4533748626708984, Accuracy = 0.7272727489471436
# Iter #1408:  Learning rate = 0.005000:   Batch Loss = 3.090787, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4774246215820312, Accuracy = 0.6969696879386902
# Iter #1416:  Learning rate = 0.005000:   Batch Loss = 3.617076, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4381816387176514, Accuracy = 0.6969696879386902
# Iter #1424:  Learning rate = 0.005000:   Batch Loss = 0.913104, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4602289199829102, Accuracy = 0.6363636255264282
# Iter #1432:  Learning rate = 0.005000:   Batch Loss = 1.015112, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4424444437026978, Accuracy = 0.6363636255264282
# Iter #1440:  Learning rate = 0.005000:   Batch Loss = 1.639576, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4542596340179443, Accuracy = 0.6060606241226196
# Iter #1448:  Learning rate = 0.005000:   Batch Loss = 1.110747, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4639687538146973, Accuracy = 0.5454545617103577
# Iter #1456:  Learning rate = 0.005000:   Batch Loss = 0.736903, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.473949909210205, Accuracy = 0.5757575631141663
# Iter #1464:  Learning rate = 0.005000:   Batch Loss = 0.769643, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.325371503829956, Accuracy = 0.6060606241226196
# Iter #1472:  Learning rate = 0.005000:   Batch Loss = 0.647151, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.2906198501586914, Accuracy = 0.7575757503509521
# Iter #1480:  Learning rate = 0.005000:   Batch Loss = 1.050633, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3041130304336548, Accuracy = 0.7575757503509521
# Iter #1488:  Learning rate = 0.005000:   Batch Loss = 1.304205, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.2718541622161865, Accuracy = 0.7575757503509521
# Iter #1496:  Learning rate = 0.005000:   Batch Loss = 0.850774, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.2615056037902832, Accuracy = 0.7575757503509521
# Iter #1504:  Learning rate = 0.005000:   Batch Loss = 1.408521, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.2652381658554077, Accuracy = 0.7272727489471436
# Iter #1512:  Learning rate = 0.005000:   Batch Loss = 1.547228, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3032689094543457, Accuracy = 0.6969696879386902
# Iter #1520:  Learning rate = 0.005000:   Batch Loss = 0.662545, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3267405033111572, Accuracy = 0.6363636255264282
# Iter #1528:  Learning rate = 0.005000:   Batch Loss = 1.791194, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.339897871017456, Accuracy = 0.6363636255264282
# Iter #1536:  Learning rate = 0.005000:   Batch Loss = 1.955322, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3838956356048584, Accuracy = 0.6060606241226196
# Iter #1544:  Learning rate = 0.005000:   Batch Loss = 2.600954, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3525707721710205, Accuracy = 0.6363636255264282
# Iter #1552:  Learning rate = 0.005000:   Batch Loss = 0.965176, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3229916095733643, Accuracy = 0.6363636255264282
# Iter #1560:  Learning rate = 0.005000:   Batch Loss = 1.468874, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.292474627494812, Accuracy = 0.6969696879386902
# Iter #1568:  Learning rate = 0.005000:   Batch Loss = 1.613638, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.2814702987670898, Accuracy = 0.7272727489471436
# Iter #1576:  Learning rate = 0.005000:   Batch Loss = 0.660086, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5120458602905273, Accuracy = 0.7272727489471436
# Iter #1584:  Learning rate = 0.005000:   Batch Loss = 2.125926, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5747675895690918, Accuracy = 0.5757575631141663
# Iter #1592:  Learning rate = 0.005000:   Batch Loss = 1.486622, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.6467703580856323, Accuracy = 0.5151515007019043
# Iter #1600:  Learning rate = 0.005000:   Batch Loss = 3.389305, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.6833457946777344, Accuracy = 0.5757575631141663
# Iter #1608:  Learning rate = 0.005000:   Batch Loss = 0.803033, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.726146936416626, Accuracy = 0.5454545617103577
# Iter #1616:  Learning rate = 0.005000:   Batch Loss = 2.091825, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.6829437017440796, Accuracy = 0.3333333432674408
# Iter #1624:  Learning rate = 0.005000:   Batch Loss = 1.251346, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.6167019605636597, Accuracy = 0.6969696879386902
# Iter #1632:  Learning rate = 0.005000:   Batch Loss = 0.619010, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4854087829589844, Accuracy = 0.6060606241226196
# Iter #1640:  Learning rate = 0.005000:   Batch Loss = 3.674832, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.826772928237915, Accuracy = 0.5454545617103577
# Iter #1648:  Learning rate = 0.005000:   Batch Loss = 0.520238, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.43374764919281, Accuracy = 0.5454545617103577
# Iter #1656:  Learning rate = 0.005000:   Batch Loss = 1.288670, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4431781768798828, Accuracy = 0.5454545617103577
# Iter #1664:  Learning rate = 0.005000:   Batch Loss = 0.946689, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5333075523376465, Accuracy = 0.42424243688583374
# Iter #1672:  Learning rate = 0.005000:   Batch Loss = 1.265614, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5485892295837402, Accuracy = 0.6060606241226196
# Iter #1680:  Learning rate = 0.005000:   Batch Loss = 0.578312, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5755082368850708, Accuracy = 0.6060606241226196
# Iter #1688:  Learning rate = 0.005000:   Batch Loss = 0.581592, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5974843502044678, Accuracy = 0.6666666865348816
# Iter #1696:  Learning rate = 0.005000:   Batch Loss = 0.726575, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.558164119720459, Accuracy = 0.6060606241226196
# Iter #1704:  Learning rate = 0.005000:   Batch Loss = 3.603362, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4357236623764038, Accuracy = 0.6666666865348816
# Iter #1712:  Learning rate = 0.005000:   Batch Loss = 1.369137, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4882689714431763, Accuracy = 0.6363636255264282
# Iter #1720:  Learning rate = 0.005000:   Batch Loss = 2.286575, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.6106007099151611, Accuracy = 0.3333333432674408
# Iter #1728:  Learning rate = 0.005000:   Batch Loss = 1.166095, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5247057676315308, Accuracy = 0.6060606241226196
# Iter #1736:  Learning rate = 0.005000:   Batch Loss = 0.848976, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5346440076828003, Accuracy = 0.6060606241226196
# Iter #1744:  Learning rate = 0.005000:   Batch Loss = 1.998045, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4952168464660645, Accuracy = 0.6363636255264282
# Iter #1752:  Learning rate = 0.005000:   Batch Loss = 1.216486, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5311830043792725, Accuracy = 0.6666666865348816
# Iter #1760:  Learning rate = 0.005000:   Batch Loss = 1.921839, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.6553363800048828, Accuracy = 0.5757575631141663
# Iter #1768:  Learning rate = 0.005000:   Batch Loss = 0.849777, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4231690168380737, Accuracy = 0.6666666865348816
# Iter #1776:  Learning rate = 0.005000:   Batch Loss = 1.799202, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3910313844680786, Accuracy = 0.6666666865348816
# Iter #1784:  Learning rate = 0.005000:   Batch Loss = 0.708345, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3925349712371826, Accuracy = 0.6363636255264282
# Iter #1792:  Learning rate = 0.005000:   Batch Loss = 0.873008, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4099299907684326, Accuracy = 0.6363636255264282
# Iter #1800:  Learning rate = 0.005000:   Batch Loss = 1.156124, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4639784097671509, Accuracy = 0.5454545617103577
# Iter #1808:  Learning rate = 0.005000:   Batch Loss = 1.337667, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5514098405838013, Accuracy = 0.5151515007019043
# Iter #1816:  Learning rate = 0.005000:   Batch Loss = 0.824437, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5263303518295288, Accuracy = 0.5151515007019043
# Iter #1824:  Learning rate = 0.005000:   Batch Loss = 3.368153, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4557631015777588, Accuracy = 0.5454545617103577
# Iter #1832:  Learning rate = 0.005000:   Batch Loss = 0.773764, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3984276056289673, Accuracy = 0.6060606241226196
# Iter #1840:  Learning rate = 0.005000:   Batch Loss = 1.258239, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3690181970596313, Accuracy = 0.6666666865348816
# Iter #1848:  Learning rate = 0.005000:   Batch Loss = 1.121361, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3635990619659424, Accuracy = 0.6666666865348816
# Iter #1856:  Learning rate = 0.005000:   Batch Loss = 1.313249, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3564212322235107, Accuracy = 0.6666666865348816
# Iter #1864:  Learning rate = 0.005000:   Batch Loss = 1.175066, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4186666011810303, Accuracy = 0.6666666865348816
# Iter #1872:  Learning rate = 0.005000:   Batch Loss = 1.125075, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.396464228630066, Accuracy = 0.6060606241226196
# Iter #1880:  Learning rate = 0.005000:   Batch Loss = 1.433695, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3590530157089233, Accuracy = 0.6060606241226196
# Iter #1888:  Learning rate = 0.005000:   Batch Loss = 1.366614, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3500580787658691, Accuracy = 0.6666666865348816
# Iter #1896:  Learning rate = 0.005000:   Batch Loss = 0.855749, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3938003778457642, Accuracy = 0.6363636255264282
# Iter #1904:  Learning rate = 0.005000:   Batch Loss = 4.190246, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4406604766845703, Accuracy = 0.6363636255264282
# Iter #1912:  Learning rate = 0.005000:   Batch Loss = 0.731827, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4403026103973389, Accuracy = 0.6363636255264282
# Iter #1920:  Learning rate = 0.005000:   Batch Loss = 1.051136, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3828619718551636, Accuracy = 0.6363636255264282
# Iter #1928:  Learning rate = 0.005000:   Batch Loss = 1.242391, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4174020290374756, Accuracy = 0.6363636255264282
# Iter #1936:  Learning rate = 0.005000:   Batch Loss = 0.673556, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.378723382949829, Accuracy = 0.6666666865348816
# Iter #1944:  Learning rate = 0.005000:   Batch Loss = 0.889368, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4202191829681396, Accuracy = 0.5757575631141663
# Iter #1952:  Learning rate = 0.005000:   Batch Loss = 0.811754, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4188505411148071, Accuracy = 0.5151515007019043
# Iter #1960:  Learning rate = 0.005000:   Batch Loss = 1.385013, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3945415019989014, Accuracy = 0.5454545617103577
# Iter #1968:  Learning rate = 0.005000:   Batch Loss = 0.685360, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3688874244689941, Accuracy = 0.5757575631141663
# Iter #1976:  Learning rate = 0.005000:   Batch Loss = 1.075218, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3829536437988281, Accuracy = 0.5757575631141663
# Iter #1984:  Learning rate = 0.005000:   Batch Loss = 0.639301, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3628417253494263, Accuracy = 0.6060606241226196
# Iter #1992:  Learning rate = 0.005000:   Batch Loss = 0.685924, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3958978652954102, Accuracy = 0.6363636255264282
# Iter #2000:  Learning rate = 0.005000:   Batch Loss = 0.644974, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3587331771850586, Accuracy = 0.6666666865348816
# Iter #2008:  Learning rate = 0.005000:   Batch Loss = 0.558182, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3738102912902832, Accuracy = 0.7272727489471436
# Iter #2016:  Learning rate = 0.005000:   Batch Loss = 0.591320, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3424086570739746, Accuracy = 0.7272727489471436
# Iter #2024:  Learning rate = 0.005000:   Batch Loss = 0.735218, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3189455270767212, Accuracy = 0.7272727489471436
# Iter #2032:  Learning rate = 0.005000:   Batch Loss = 0.511034, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.323690414428711, Accuracy = 0.6969696879386902
# Iter #2040:  Learning rate = 0.005000:   Batch Loss = 2.114864, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3510130643844604, Accuracy = 0.5757575631141663
# Iter #2048:  Learning rate = 0.005000:   Batch Loss = 0.638618, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.359428882598877, Accuracy = 0.5757575631141663
# Iter #2056:  Learning rate = 0.005000:   Batch Loss = 0.949789, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3094377517700195, Accuracy = 0.6666666865348816
# Iter #2064:  Learning rate = 0.005000:   Batch Loss = 0.822130, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3505439758300781, Accuracy = 0.6666666865348816
# Iter #2072:  Learning rate = 0.005000:   Batch Loss = 0.594959, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.2967292070388794, Accuracy = 0.6666666865348816
# Iter #2080:  Learning rate = 0.005000:   Batch Loss = 0.590589, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.235337495803833, Accuracy = 0.6666666865348816
# Iter #2088:  Learning rate = 0.005000:   Batch Loss = 0.926096, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.2273813486099243, Accuracy = 0.6969696879386902
# Iter #2096:  Learning rate = 0.005000:   Batch Loss = 3.131751, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.2848033905029297, Accuracy = 0.6969696879386902
# Iter #2104:  Learning rate = 0.005000:   Batch Loss = 3.977197, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.353792667388916, Accuracy = 0.6666666865348816
# Iter #2112:  Learning rate = 0.005000:   Batch Loss = 0.904692, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.439647912979126, Accuracy = 0.5151515007019043
# Iter #2120:  Learning rate = 0.005000:   Batch Loss = 1.278176, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.467509388923645, Accuracy = 0.5151515007019043
# Iter #2128:  Learning rate = 0.005000:   Batch Loss = 0.539578, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3721702098846436, Accuracy = 0.5454545617103577
# ...
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4364750385284424, Accuracy = 0.5757575631141663
# Iter #2984:  Learning rate = 0.005000:   Batch Loss = 0.572375, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5111899375915527, Accuracy = 0.5757575631141663
# Iter #2992:  Learning rate = 0.005000:   Batch Loss = 0.632911, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4056260585784912, Accuracy = 0.6060606241226196
# Iter #3000:  Learning rate = 0.005000:   Batch Loss = 1.469658, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3383660316467285, Accuracy = 0.6363636255264282
# Iter #3008:  Learning rate = 0.005000:   Batch Loss = 0.415760, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3031504154205322, Accuracy = 0.6666666865348816
# Iter #3016:  Learning rate = 0.005000:   Batch Loss = 1.864364, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.2890706062316895, Accuracy = 0.7272727489471436
# Iter #3024:  Learning rate = 0.005000:   Batch Loss = 1.103666, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3763298988342285, Accuracy = 0.5757575631141663
# Iter #3032:  Learning rate = 0.005000:   Batch Loss = 1.412517, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3813093900680542, Accuracy = 0.6969696879386902
# Iter #3040:  Learning rate = 0.005000:   Batch Loss = 0.533538, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.400984764099121, Accuracy = 0.6060606241226196
# Iter #3048:  Learning rate = 0.005000:   Batch Loss = 2.086612, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4447823762893677, Accuracy = 0.6363636255264282
# Iter #3056:  Learning rate = 0.005000:   Batch Loss = 0.392452, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.356597900390625, Accuracy = 0.6363636255264282
# Iter #3064:  Learning rate = 0.005000:   Batch Loss = 0.936310, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3384764194488525, Accuracy = 0.6666666865348816
# Iter #3072:  Learning rate = 0.005000:   Batch Loss = 1.280992, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3206360340118408, Accuracy = 0.6666666865348816
# Iter #3080:  Learning rate = 0.005000:   Batch Loss = 2.752801, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.319879174232483, Accuracy = 0.6969696879386902
# Iter #3088:  Learning rate = 0.005000:   Batch Loss = 1.003694, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3149104118347168, Accuracy = 0.7272727489471436
# Iter #3096:  Learning rate = 0.005000:   Batch Loss = 0.569162, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.281691074371338, Accuracy = 0.6969696879386902
# Iter #3104:  Learning rate = 0.005000:   Batch Loss = 0.922322, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.2646808624267578, Accuracy = 0.7272727489471436
# Iter #3112:  Learning rate = 0.005000:   Batch Loss = 0.944042, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.2501533031463623, Accuracy = 0.7272727489471436
# Iter #3120:  Learning rate = 0.005000:   Batch Loss = 0.622349, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.2858738899230957, Accuracy = 0.6969696879386902
# Iter #3128:  Learning rate = 0.005000:   Batch Loss = 0.513229, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3855392932891846, Accuracy = 0.7272727489471436
# Iter #3136:  Learning rate = 0.005000:   Batch Loss = 0.990164, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.445286750793457, Accuracy = 0.6666666865348816
# Iter #3144:  Learning rate = 0.005000:   Batch Loss = 0.463559, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4733319282531738, Accuracy = 0.6666666865348816
# Iter #3152:  Learning rate = 0.005000:   Batch Loss = 0.408307, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4301475286483765, Accuracy = 0.5757575631141663
# Iter #3160:  Learning rate = 0.005000:   Batch Loss = 0.467307, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.359529972076416, Accuracy = 0.6969696879386902
# Iter #3168:  Learning rate = 0.005000:   Batch Loss = 0.465588, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3272676467895508, Accuracy = 0.6363636255264282
# Iter #3176:  Learning rate = 0.005000:   Batch Loss = 1.341585, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3408863544464111, Accuracy = 0.6666666865348816
# Iter #3184:  Learning rate = 0.005000:   Batch Loss = 0.447122, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3321187496185303, Accuracy = 0.7272727489471436
# Iter #3192:  Learning rate = 0.005000:   Batch Loss = 0.744933, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.2728763818740845, Accuracy = 0.6666666865348816
# Iter #3200:  Learning rate = 0.005000:   Batch Loss = 0.513521, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.2494781017303467, Accuracy = 0.7272727489471436
# Iter #3208:  Learning rate = 0.005000:   Batch Loss = 0.556899, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.168700933456421, Accuracy = 0.7272727489471436
# Iter #3216:  Learning rate = 0.005000:   Batch Loss = 0.767469, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.200429916381836, Accuracy = 0.6969696879386902
# Iter #3224:  Learning rate = 0.005000:   Batch Loss = 0.491695, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3327041864395142, Accuracy = 0.6969696879386902
# Iter #3232:  Learning rate = 0.005000:   Batch Loss = 0.764798, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.2838969230651855, Accuracy = 0.6969696879386902
# Iter #3240:  Learning rate = 0.005000:   Batch Loss = 0.596130, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3185707330703735, Accuracy = 0.6666666865348816
# Iter #3248:  Learning rate = 0.005000:   Batch Loss = 2.205488, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.36643385887146, Accuracy = 0.6060606241226196
# Iter #3256:  Learning rate = 0.005000:   Batch Loss = 1.194025, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3749072551727295, Accuracy = 0.6666666865348816
# Iter #3264:  Learning rate = 0.005000:   Batch Loss = 1.044944, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4479339122772217, Accuracy = 0.5454545617103577
# Iter #3272:  Learning rate = 0.005000:   Batch Loss = 0.411179, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4418907165527344, Accuracy = 0.6060606241226196
# Iter #3280:  Learning rate = 0.005000:   Batch Loss = 0.602266, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4226741790771484, Accuracy = 0.6363636255264282
# Iter #3288:  Learning rate = 0.005000:   Batch Loss = 1.978294, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.372348666191101, Accuracy = 0.6060606241226196
# Iter #3296:  Learning rate = 0.005000:   Batch Loss = 1.543194, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.2533457279205322, Accuracy = 0.6060606241226196
# Iter #3304:  Learning rate = 0.005000:   Batch Loss = 1.286783, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.2373695373535156, Accuracy = 0.6666666865348816
# Iter #3312:  Learning rate = 0.005000:   Batch Loss = 0.383279, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.2696138620376587, Accuracy = 0.6060606241226196
# Iter #3320:  Learning rate = 0.005000:   Batch Loss = 0.503372, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.2919976711273193, Accuracy = 0.6363636255264282
# Iter #3328:  Learning rate = 0.005000:   Batch Loss = 0.426391, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3567554950714111, Accuracy = 0.6060606241226196
# Iter #3336:  Learning rate = 0.005000:   Batch Loss = 0.475116, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.39866042137146, Accuracy = 0.6363636255264282
# Iter #3344:  Learning rate = 0.005000:   Batch Loss = 0.428006, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4609136581420898, Accuracy = 0.5757575631141663
# Iter #3352:  Learning rate = 0.005000:   Batch Loss = 0.423655, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4785410165786743, Accuracy = 0.5757575631141663
# Iter #3360:  Learning rate = 0.005000:   Batch Loss = 0.427661, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4829318523406982, Accuracy = 0.5757575631141663
# Iter #3368:  Learning rate = 0.005000:   Batch Loss = 2.069657, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3857126235961914, Accuracy = 0.6060606241226196
# Iter #3376:  Learning rate = 0.005000:   Batch Loss = 0.943594, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4329677820205688, Accuracy = 0.6060606241226196
# Iter #3384:  Learning rate = 0.005000:   Batch Loss = 0.445270, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4753828048706055, Accuracy = 0.5757575631141663
# Iter #3392:  Learning rate = 0.005000:   Batch Loss = 0.645093, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4919400215148926, Accuracy = 0.6060606241226196
# Iter #3400:  Learning rate = 0.005000:   Batch Loss = 0.380890, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5388164520263672, Accuracy = 0.5454545617103577
# Iter #3408:  Learning rate = 0.005000:   Batch Loss = 0.615227, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.5062497854232788, Accuracy = 0.6060606241226196
# Iter #3416:  Learning rate = 0.005000:   Batch Loss = 0.812249, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3893096446990967, Accuracy = 0.6969696879386902
# Iter #3424:  Learning rate = 0.005000:   Batch Loss = 0.584083, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3334110975265503, Accuracy = 0.6969696879386902
# Iter #3432:  Learning rate = 0.005000:   Batch Loss = 0.520746, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3245115280151367, Accuracy = 0.6969696879386902
# Iter #3440:  Learning rate = 0.005000:   Batch Loss = 0.475091, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.300964117050171, Accuracy = 0.6969696879386902
# Iter #3448:  Learning rate = 0.005000:   Batch Loss = 1.013558, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.2700817584991455, Accuracy = 0.6666666865348816
# Iter #3456:  Learning rate = 0.005000:   Batch Loss = 0.469550, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.179717779159546, Accuracy = 0.7272727489471436
# Iter #3464:  Learning rate = 0.005000:   Batch Loss = 0.511551, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.2651500701904297, Accuracy = 0.7272727489471436
# Iter #3472:  Learning rate = 0.005000:   Batch Loss = 1.532682, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.2659496068954468, Accuracy = 0.7575757503509521
# Iter #3480:  Learning rate = 0.005000:   Batch Loss = 0.557873, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3129549026489258, Accuracy = 0.7272727489471436
# Iter #3488:  Learning rate = 0.005000:   Batch Loss = 0.499114, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.2698090076446533, Accuracy = 0.7272727489471436
# Iter #3496:  Learning rate = 0.005000:   Batch Loss = 0.493452, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.283308744430542, Accuracy = 0.6666666865348816
# Iter #3504:  Learning rate = 0.005000:   Batch Loss = 0.561155, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3438209295272827, Accuracy = 0.6666666865348816
# Iter #3512:  Learning rate = 0.005000:   Batch Loss = 0.467399, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3433191776275635, Accuracy = 0.6666666865348816
# Iter #3520:  Learning rate = 0.005000:   Batch Loss = 0.484054, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3656723499298096, Accuracy = 0.6363636255264282
# Iter #3528:  Learning rate = 0.005000:   Batch Loss = 0.877184, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.340360164642334, Accuracy = 0.5757575631141663
# Iter #3536:  Learning rate = 0.005000:   Batch Loss = 0.463195, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.2921102046966553, Accuracy = 0.6666666865348816
# Iter #3544:  Learning rate = 0.005000:   Batch Loss = 0.432489, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.2477517127990723, Accuracy = 0.6666666865348816
# Iter #3552:  Learning rate = 0.005000:   Batch Loss = 0.416997, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3294918537139893, Accuracy = 0.6363636255264282
# Iter #3560:  Learning rate = 0.005000:   Batch Loss = 3.559591, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.389426350593567, Accuracy = 0.6363636255264282
# Iter #3568:  Learning rate = 0.005000:   Batch Loss = 0.584146, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3885976076126099, Accuracy = 0.6969696879386902
# Iter #3576:  Learning rate = 0.005000:   Batch Loss = 0.734886, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.310927152633667, Accuracy = 0.6969696879386902
# Iter #3584:  Learning rate = 0.005000:   Batch Loss = 0.722085, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.239659070968628, Accuracy = 0.6969696879386902
# Iter #3592:  Learning rate = 0.005000:   Batch Loss = 0.635692, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.2405047416687012, Accuracy = 0.7272727489471436
# Iter #3600:  Learning rate = 0.005000:   Batch Loss = 0.423377, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.276595115661621, Accuracy = 0.7272727489471436
# Iter #3608:  Learning rate = 0.005000:   Batch Loss = 1.665482, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.1901216506958008, Accuracy = 0.6969696879386902
# Iter #3616:  Learning rate = 0.005000:   Batch Loss = 0.427076, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.0798380374908447, Accuracy = 0.7272727489471436
# Iter #3624:  Learning rate = 0.005000:   Batch Loss = 0.960581, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.1139578819274902, Accuracy = 0.7272727489471436
# Iter #3632:  Learning rate = 0.005000:   Batch Loss = 0.431738, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.216314673423767, Accuracy = 0.6363636255264282
# Iter #3640:  Learning rate = 0.005000:   Batch Loss = 0.820362, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3015992641448975, Accuracy = 0.6363636255264282
# Iter #3648:  Learning rate = 0.005000:   Batch Loss = 0.388377, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3917982578277588, Accuracy = 0.6060606241226196
# Iter #3656:  Learning rate = 0.005000:   Batch Loss = 0.725447, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.4801279306411743, Accuracy = 0.5757575631141663
# Iter #3664:  Learning rate = 0.005000:   Batch Loss = 0.764739, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.422389030456543, Accuracy = 0.5757575631141663
# Iter #3672:  Learning rate = 0.005000:   Batch Loss = 1.523316, Accuracy = 0.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3626893758773804, Accuracy = 0.6363636255264282
# Iter #3680:  Learning rate = 0.005000:   Batch Loss = 0.659483, Accuracy = 1.0
# PERFORMANCE ON TEST SET:             Batch Loss = 1.3129942417144775, Accuracy = 0.6363636255264282
# Optimization Finished!
# FINAL RESULT: Batch Loss = 1.3129942417144775, Accuracy = 0.6363636255264282
# TOTAL TIME:  101.60999774932861

# %%
# (Inline plots: )
# %matplotlib inline

font = {
    'family' : 'Bitstream Vera Sans',
    'weight' : 'bold',
    'size'   : 18
}
plt.rc('font', **font)

width = 12
height = 12
plt.figure(figsize=(width, height))

indep_train_axis = np.array(range(batch_size, (len(train_losses)+1)*batch_size, batch_size))
#plt.plot(indep_train_axis, np.array(train_losses),     "b--", label="Train losses")
plt.plot(indep_train_axis, np.array(train_accuracies), "g--", label="Train accuracies")

indep_test_axis = np.append(
    np.array(range(batch_size, len(test_losses)*display_iter, display_iter)[:-1]),
    [training_iters]
)
#plt.plot(indep_test_axis, np.array(test_losses), "b-", linewidth=2.0, label="Test losses")
plt.plot(indep_test_axis, np.array(test_accuracies), "b-", linewidth=2.0, label="Test accuracies")
print(len(test_accuracies))
print(len(train_accuracies))

plt.title("Training session's Accuracy over Iterations")
plt.legend(loc='lower right', shadow=True)
plt.ylabel('Training Accuracy')
plt.xlabel('Training Iteration')

plt.show()

# Results

predictions = one_hot_predictions.argmax(1)

print("Testing Accuracy: {}%".format(100*accuracy))

print("")
print("Precision: {}%".format(100*metrics.precision_score(y_test, predictions, average="weighted")))
print("Recall: {}%".format(100*metrics.recall_score(y_test, predictions, average="weighted")))
print("f1_score: {}%".format(100*metrics.f1_score(y_test, predictions, average="weighted")))

print("")
print("Confusion Matrix:")
print("Created using test set of {} datapoints, normalised to % of each class in the test dataset".format(len(y_test)))
confusion_matrix = metrics.confusion_matrix(y_test, predictions)


#print(confusion_matrix)
normalised_confusion_matrix = np.array(confusion_matrix, dtype=np.float32)/np.sum(confusion_matrix)*100


# Plot Results: 
width = 12
height = 12
plt.figure(figsize=(width, height))
plt.imshow(
    normalised_confusion_matrix, 
    interpolation='nearest', 
    cmap=plt.cm.Blues
)
plt.title("Confusion matrix \n(normalised to % of total test data)")
plt.colorbar()
tick_marks = np.arange(n_classes)
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
sess.close()
# Out:
# 462
# 3680
# /usr/local/lib/python3.6/dist-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))
# Testing Accuracy: 63.63636255264282%
#
# Precision: 64.49106449106449%
# Recall: 63.63636363636363%
# f1_score: 62.91259964423382%
#
# Confusion Matrix:
# Created using test set of 33 datapoints, normalised to % of each class in the test dataset
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
label_encoder.inverse_transform([0,1,2,3])
# Out:
# array(['falling', 'lying', 'sitting', 'walking'], dtype='<U7')
